# %%
from flask import Flask, render_template, url_for

app = Flask('__name__')

@app.route("/")
def index():
    with open('book_viewer/data/toc.txt') as f:
        contents = f.readlines()
    return render_template('index.html', contents = contents)

# %%
with open('book_viewer/data/toc.txt') as f:
    content = f.readlines()

# %%
app.run(debug = False, port = 5005)
# Out:
#  * Serving Flask app '__name__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5005
# Press CTRL+C to quit
# 127.0.0.1 - - [27/Oct/2025 17:36:55] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Oct/2025 17:36:55] "GET /static/stylesheets/book_viewer.css HTTP/1.1" 304 -
# 127.0.0.1 - - [27/Oct/2025 17:36:55] "GET /static/stylesheets/fonts.css HTTP/1.1" 304 -
# 127.0.0.1 - - [27/Oct/2025 17:36:55] "GET /static/stylesheets/pure-min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [27/Oct/2025 17:36:55] "GET /static/javascripts/ui.js HTTP/1.1" 304 -
# 127.0.0.1 - - [27/Oct/2025 17:36:55] "GET /static/fonts/vollkorn-v6-latin-regular.woff2 HTTP/1.1" 304 -

# %%
with open('book_viewer/data/chp1.txt') as f:
    content = f.readlines()

# %%
with open('book_viewer/data/toc.txt') as f:
        contents = f.readlines()

# %%
'ab'.isdigit()
# Out:
# False

# %%
a = [1,2,3]

# %%
a.index(2)
# Out:
# 1

# %%
a = "this is not right"

# %%
def embolden(para, term):
    return para.replace(term, f'<strong>{term}</strong>')

# %%
embolden(a, 'is')
# Out:
# 'th<strong>is</strong> <strong>is</strong> not right'
