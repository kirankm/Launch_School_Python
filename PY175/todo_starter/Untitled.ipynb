# %%
x = [1,2,3,5,6]

# %%
if any(x > 3)
# Out:
#   Cell In[2], line 1
#     if any(x > 3)
#                  ^
# SyntaxError: expected ':'

# %%
any([val > 6 for val in x])
# Out:
# False

# %%
from utils import *

# %%
error_for_list_title
# Out:
# <function utils.error_for_list_title(title, lists)>
