# %%
import yaml

# %%
with open('users.yaml', 'r') as f:
    users = yaml.safe_load(f)

# %%
users
# Out:
# {'jamy': {'email': 'jamy.rustenburg@gmail.com',
#   'interests': ['woodworking', 'cooking', 'reading']},
#  'nora': {'email': 'nora.alnes@yahoo.com',
#   'interests': ['cycling', 'basketball', 'economics']},
#  'hiroko': {'email': 'hiroko.ohara@hotmail.com', 'interests': []}}

# %%
[interest for user in users.values() for interest in user['interests'] ]
# Out:
# ['woodworking', 'cooking', 'reading', 'cycling', 'basketball', 'economics']
